# %%
import pandas as pd

# %%
VeitClub = pd.read_csv('DATA/Veit-Club')
Schoepferwissen = pd.read_csv('DATA/SchöpferwissenTV.csv')
WegFreiheit = pd.read_csv('Der Weg in deine Freiheit.csv')

# %%
Schoepferwissen
# Out:
#                                                  title  views  \
# 0                                   Code Wort:Covid 19    940
# 1    BRAKING NEWS!!! PART I : Schokierende Wahrheit...   1275
# 2                                     Die heisse Phase   1501
# 3    DAS GRÖSSTE VERBRECHEN AN DER MENSCHEIT - wir ...   2083
# 4                           CARS GO BACK TO THE OWNERS    765
# ..                                                 ...    ...
# 933  Wie aus Göttern Affen wurden - Auf dem Weg zum...   8477
# 934   Wie aus Göttern Affen wurden - Thomas a.d.F.Veit   8267
# 935      Anunnaki Teil1 - Wie aus Göttern Affen wurden  64092
# 936    Wie aus Göttern Affen wurden - Buchbeschreibung   4938
# 937  Wie aus Göttern Affen wurden - Julias Buchbesc...   4777
#
#                                            description date_published  \
# 0               Sind wir Teil eines MEGA Komplotts?!?!     2022-03-14
# 1    Die neue Fernstudiumsreihe mit nie dagewesen D...     2022-02-07
# 2    *please add English Subtitle!!! (download Vide...     2022-01-15
# 3    An die , die ad hoc Zeit haben: Verschriftlich...     2022-01-13
# 4                                                  NaN     2022-01-12
# ..                                                 ...            ...
# 933  www.geisteskraft-thailand.comhttps://aufdemweg...     2015-08-31
# 934  www.geisteskraft-thailand.comhttps://aufdemweg...     2015-08-25
# 935  www.geisteskraft-thailand.comhttps://aufdemweg...     2015-08-25
# 936  www.geisteskraft-thailand.comhttps://aufdemweg...     2015-08-07
# 937              Unser Zweites Video aus dem Jahr 2015     2015-08-07
#
#     duration                                               tags
# 0      24:36                                                NaN
# 1        NaN                                                NaN
# 2      23:40                                                NaN
# 3      44:58                                                NaN
# 4      12:53                                                NaN
# ..       ...                                                ...
# 933    47:44  Glauben, Wissen, Bewusstsein, Seele, Geist, Ve...
# 934  1:06:14  Schöpferwissen, Bewusstsein, Seele, Geist, Wah...
# 935  1:45:32  Reptiloide, Shapeshifter, Blaublüter, Schöpfer...
# 936    12:49  Götter, Affen, NWO, Rotschild, Banken, Geld, M...
# 937    11:51  Götter, Affen, Bewusstsein, Seele, Geist, Vers...
#
# [938 rows x 6 columns]

# %%
#Datenset geordnet nach den meisten Views
df = Schoepferwissen.sort_values(by = ["views"], ascending= False, inplace = False)
df
# Out:
#                                                  title  views  \
# 935      Anunnaki Teil1 - Wie aus Göttern Affen wurden  64092
# 930  Anunnaki - Die gefälschte Realität - Wie aus G...  53737
# 931    Anunnaki Teil 2  - Wie aus Göttern Affen wurden  22190
# 866  Gor Timofey Rassadin - Neugeburt der Erde und ...  22016
# 872  Geistheiler Sananda: Indigos & Reptiloiden in ...  20400
# ..                                                 ...    ...
# 572                         Finde deinen Seelenpartner    159
# 577                                  Compact gesteuert    142
# 569  Realitatstgestaltung wie sie richtig funktioniert    138
# 567  Transhumanuismus ab sofort überall kostenfrei ...    130
# 574                          Die Wiedergeburt der Erde     93
#
#                                            description date_published  \
# 935  www.geisteskraft-thailand.comhttps://aufdemweg...     2015-08-25
# 930  www.geisteskraft-thailand.comhttps://aufdemweg...     2015-09-19
# 931                                     September 2015     2015-09-18
# 866  www.geisteskraft-thailand.comhttps://aufdemweg...     2016-06-03
# 872                                                Vid     2016-04-02
# ..                                                 ...            ...
# 572                       www.ubc-unabellacompania.com     2017-08-20
# 577                       www.ubc-unabellacompania.com     2017-08-20
# 569                       www.ubc-unabellacompania.com     2017-08-20
# 567                       www.ubc-unabellacompania.com     2017-08-20
# 574                       www.ubc-unabellacompania.com     2017-08-20
#
#     duration                                               tags
# 935  1:45:32  Reptiloide, Shapeshifter, Blaublüter, Schöpfer...
# 930    11:39  Wie aus Göttern Affen wurdn, Schöpferwissen TV...
# 931    56:17  Anunnaki, Reptiloide, Elite, Schöpferwissen, B...
# 866    47:47  Gor Timofley Rassadin, Querdenken TV, Michael ...
# 872      NaN  Indigos, Reptiloiden, Schöpferwissen TV, Geist...
# ..       ...                                                ...
# 572      NaN  Thomas Veit, Thailand Project, Seelenpartner, ...
# 577      NaN  Compact gesteuert, Thomas Veit, Wertschätzung,...
# 569      NaN  Realitätsgestaltung, Erkennen, verstehen, Hand...
# 567      NaN  Transhumanismus, Sinnestäuschungen, Umbau des ...
# 574      NaN  Thomas Veit, Wiedergeburt der Erde, Erdgebunde...
#
# [938 rows x 6 columns]

# %%
#Geordnet nach Datum
Schoepferwissen.sort_values(by = 'date_published')
# Out:
#                                                  title  views  \
# 937  Wie aus Göttern Affen wurden - Julias Buchbesc...   4777
# 936    Wie aus Göttern Affen wurden - Buchbeschreibung   4938
# 934   Wie aus Göttern Affen wurden - Thomas a.d.F.Veit   8267
# 935      Anunnaki Teil1 - Wie aus Göttern Affen wurden  64092
# 933  Wie aus Göttern Affen wurden - Auf dem Weg zum...   8477
# ..                                                 ...    ...
# 4                           CARS GO BACK TO THE OWNERS    765
# 3    DAS GRÖSSTE VERBRECHEN AN DER MENSCHEIT - wir ...   2083
# 2                                     Die heisse Phase   1501
# 1    BRAKING NEWS!!! PART I : Schokierende Wahrheit...   1275
# 0                                   Code Wort:Covid 19    940
#
#                                            description date_published  \
# 937              Unser Zweites Video aus dem Jahr 2015     2015-08-07
# 936  www.geisteskraft-thailand.comhttps://aufdemweg...     2015-08-07
# 934  www.geisteskraft-thailand.comhttps://aufdemweg...     2015-08-25
# 935  www.geisteskraft-thailand.comhttps://aufdemweg...     2015-08-25
# 933  www.geisteskraft-thailand.comhttps://aufdemweg...     2015-08-31
# ..                                                 ...            ...
# 4                                                  NaN     2022-01-12
# 3    An die , die ad hoc Zeit haben: Verschriftlich...     2022-01-13
# 2    *please add English Subtitle!!! (download Vide...     2022-01-15
# 1    Die neue Fernstudiumsreihe mit nie dagewesen D...     2022-02-07
# 0               Sind wir Teil eines MEGA Komplotts?!?!     2022-03-14
#
#     duration                                               tags
# 937    11:51  Götter, Affen, Bewusstsein, Seele, Geist, Vers...
# 936    12:49  Götter, Affen, NWO, Rotschild, Banken, Geld, M...
# 934  1:06:14  Schöpferwissen, Bewusstsein, Seele, Geist, Wah...
# 935  1:45:32  Reptiloide, Shapeshifter, Blaublüter, Schöpfer...
# 933    47:44  Glauben, Wissen, Bewusstsein, Seele, Geist, Ve...
# ..       ...                                                ...
# 4      12:53                                                NaN
# 3      44:58                                                NaN
# 2      23:40                                                NaN
# 1        NaN                                                NaN
# 0      24:36                                                NaN
#
# [938 rows x 6 columns]

# %%
#Die 3 Video mit den wenigsten Views
Schoepferwissen.nsmallest(3, 'views')
# Out:
#                                                  title  views  \
# 574                          Die Wiedergeburt der Erde     93
# 567  Transhumanuismus ab sofort überall kostenfrei ...    130
# 569  Realitatstgestaltung wie sie richtig funktioniert    138
#
#                       description date_published duration  \
# 574  www.ubc-unabellacompania.com     2017-08-20      NaN
# 567  www.ubc-unabellacompania.com     2017-08-20      NaN
# 569  www.ubc-unabellacompania.com     2017-08-20      NaN
#
#                                                   tags
# 574  Thomas Veit, Wiedergeburt der Erde, Erdgebunde...
# 567  Transhumanismus, Sinnestäuschungen, Umbau des ...
# 569  Realitätsgestaltung, Erkennen, verstehen, Hand...

# %%
#Filter nach "String"
tags = ['Geist']
filt = Schoepferwissen['tags'].str.contains('Transhumanismus', na= False)
Schoepf_filt = Schoepferwissen.loc[filt]
len(Schoepf_filt)
# Out:
# 64

# %%
#Einzelne Einträge auslesen
Schoepferwissen['tags'][314]
# Out:
# 'Geist, Seele, Bewusstsein, NWO, New World Order, New Age, Russische Bewusstseinsforscher, Weltraum, Sonne, Spiel Welt, Mensch, UBC, neu, bewusst, Matrix, Transhumanismus, Endzeit, Quantensprung, Kritik, Affen, Frei, TV, Denken, Wissen, geisteskraft, thailand, una bella compania'

# %%
#Statisitische Standartwerte geht nur bei Zahlen...
Schoepferwissen.describe()
# Out:
#               views
# count    938.000000
# mean    2779.997868
# std     3633.150620
# min       93.000000
# 25%     1178.250000
# 50%     1778.500000
# 75%     3302.000000
# max    64092.000000

# %%
Schoepferwissen.plot(x="date_published", y='views')

# %%
WegFreiheit["transcript"][20]
# Out:
# '[{\'text\': \'hallo im kanal schöpfer wissen tv\', \'start\': 8.11, \'duration\': 5.64}, {\'text\': \'schöpfer wissen thomas veit\', \'start\': 11.059, \'duration\': 5.491}, {\'text\': \'ich bin julia viele von euch haben\', \'start\': 13.75, \'duration\': 4.21}, {\'text\': \'wahrscheinlich den jüngsten\', \'start\': 16.55, \'duration\': 2.88}, {\'text\': \'zusammenschnitt von uns gesehen\', \'start\': 17.96, \'duration\': 3.99}, {\'text\': \'danke für die ganzen rückmeldung der ist\', \'start\': 19.43, \'duration\': 4.68}, {\'text\': \'tatsächlich ziemlich gut angekommen denn\', \'start\': 21.95, \'duration\': 4.5}, {\'text\': \'wie soll es auch anders sein denn dieser\', \'start\': 24.11, \'duration\': 5.28}, {\'text\': \'ausschnitt zeigt ziemlich gut die\', \'start\': 26.45, \'duration\': 5.31}, {\'text\': \'entwicklungsgeschichte von schöpfer\', \'start\': 29.39, \'duration\': 6.3}, {\'text\': \'wissen tv von thomas von dem erkenntnis\', \'start\': 31.76, \'duration\': 7.139}, {\'text\': \'weg den er gegangen ist und auch worum\', \'start\': 35.69, \'duration\': 6.209}, {\'text\': \'es wirklich geht für alle die die an\', \'start\': 38.899, \'duration\': 4.23}, {\'text\': \'dieser stelle sagen hör welcher\', \'start\': 41.899, \'duration\': 2.94}, {\'text\': \'zusammenschnitt ich weiß nicht wovon sie\', \'start\': 43.129, \'duration\': 4.14}, {\'text\': \'redet schaut ihn euch an\', \'start\': 44.839, \'duration\': 6.15}, {\'text\': \'der titel lautet keine angst denn nur\', \'start\': 47.269, \'duration\': 7.651}, {\'text\': \'die wahrheit hat bestand und ich habe\', \'start\': 50.989, \'duration\': 5.34}, {\'text\': \'heute mal wieder eine idyllische kulisse\', \'start\': 54.92, \'duration\': 4.59}, {\'text\': \'gewählt und es scheint alles so\', \'start\': 56.329, \'duration\': 6.361}, {\'text\': \'harmonisch und friedlich und einfach nur\', \'start\': 59.51, \'duration\': 3.989}, {\'text\': \'schön\', \'start\': 62.69, \'duration\': 4.2}, {\'text\': \'in der natur zu sein julia sieht heute\', \'start\': 63.499, \'duration\': 6.241}, {\'text\': \'mal wieder frisch aus und alles ist\', \'start\': 66.89, \'duration\': 3.96}, {\'text\': \'irgendwie gut oder\', \'start\': 69.74, \'duration\': 5.04}, {\'text\': \'oder ist es doch da nur schein ja warum\', \'start\': 70.85, \'duration\': 5.189}, {\'text\': \'geht worum geht es auch in dem\', \'start\': 74.78, \'duration\': 3.6}, {\'text\': \'zusammenschnitt schöpfer wissen tv ist\', \'start\': 76.039, \'duration\': 4.08}, {\'text\': \'gestartet thomas und ich haben uns\', \'start\': 78.38, \'duration\': 4.919}, {\'text\': \'kennengelernt und haben angefangen\', \'start\': 80.119, \'duration\': 4.831}, {\'text\': \'näheren kontakt zu pflegen durch sein\', \'start\': 83.299, \'duration\': 5.07}, {\'text\': \'buch wie das geschaffen wurden und vor\', \'start\': 84.95, \'duration\': 5.73}, {\'text\': \'allen dingen auch durch die schöpfer\', \'start\': 88.369, \'duration\': 5.46}, {\'text\': \'lehre von gregory grabe weit denn darin\', \'start\': 90.68, \'duration\': 5.13}, {\'text\': \'wurde damals damals in thailand projekt\', \'start\': 93.829, \'duration\': 3.6}, {\'text\': \'ausgebildet ich weiß meisten von euch\', \'start\': 95.81, \'duration\': 4.47}, {\'text\': \'wissen ist und es ging darum geistige\', \'start\': 97.429, \'duration\': 6.091}, {\'text\': \'techniken zu nutzen um seine eigene\', \'start\': 100.28, \'duration\': 5.339}, {\'text\': \'rettung zu vollführen was immer das dann\', \'start\': 103.52, \'duration\': 4.83}, {\'text\': \'auch bedeutet und ebenso dinge wie\', \'start\': 105.619, \'duration\': 9.771}, {\'text\': \'gesundheit geld schönheit ewige jugend\', \'start\': 108.35, \'duration\': 7.04}, {\'text\': \'talente bekommen und so weiter und so\', \'start\': 116.32, \'duration\': 7.39}, {\'text\': \'weiter darum ging und das ganze wurde\', \'start\': 120.5, \'duration\': 5.28}, {\'text\': \'von uns praktizierten angewendet also\', \'start\': 123.71, \ ...
