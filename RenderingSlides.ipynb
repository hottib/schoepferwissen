# %%
import pandas as pd
import os, glob
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
import datetime as date
import dateutil
import random

random.seed(123123123)
folder = "DATA\Working"
path = os.path.join(folder, "*.csv")
all_CSVs = glob.glob(path)
#print(path)
#print(all_CSVs)
#load all dfs an merge to one

def load_df():
    df_meta = []
    all_channel_names = []
    df_meta = pd.DataFrame(df_meta)
    for csv in all_CSVs: 
        filename = os.path.basename(csv)
        if filename[-13:] == "automated.csv":
            channelName = filename.replace(filename[-14:], "")
            df = pd.read_csv(csv)
            df["Channel"]= channelName
            index = [i for i in range(len(df))]
            df.set_index([index, 'Channel'], inplace= True)
            frames = [df_meta, df]
            df_meta = pd.concat(frames)
            if channelName not in all_channel_names:
                all_channel_names.append(channelName)
    return df_meta, all_channel_names
[df_meta, all_channel_names] = load_df()


#create unique colors
colors=[]
for c in all_channel_names:
    color = []
    for i in range(3):
        x = round(random.uniform(0, 1),2)
        color.append(x)
    colors.append(color)
print(colors)
Wahrheit = df_meta.loc[df_meta.index.get_level_values("Channel") == "Der Wahrheit verpflichtet"]
Schöpfer = df_meta.loc[df_meta.index.get_level_values("Channel") == "Schöpferwissen TV"]
Alles = df_meta.loc[df_meta.index.get_level_values("Channel") == "ALLESUNDNICHTS"]
Drachentöter = df_meta.loc[df_meta.index.get_level_values("Channel") == "DRACHENTÖTER TV"]
Freiheit = df_meta.loc[df_meta.index.get_level_values("Channel") == "Der Weg in deine Freiheit"]
Rettung = df_meta.loc[df_meta.index.get_level_values("Channel") == 'Rettung der Menschheit TV']
UBC = df_meta.loc[df_meta.index.get_level_values("Channel") == 'UBC TV']
VeitClub = df_meta.loc[df_meta.index.get_level_values("Channel") == 'VEIT CLUB']

df_collection = [Wahrheit, Schöpfer, Alles, Drachentöter, Freiheit, Rettung, UBC, VeitClub]
df_collection = []
ch_names = df_meta.index.get_level_values(1).unique()
for i in ch_names:
    print(i)
    df = df_meta.loc[df_meta.index.get_level_values("Channel") == i]
    df_collection.append(df)
    
print(len(df_collection))
    
    

print(Schöpfer.columns)
display(Schöpfer[['publish_date', 'id', 'title', 'description', 'keywords', 'length',
       'views', 'age_restricted', 'yt_caption_info', 'yt_caption_tracks',
       'vid_info']][0:2])
# Out:
# []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-3271449caf04> in <module>
#      45     colors.append(color)
#      46 print(colors)
# ---> 47 Wahrheit = df_meta.loc[df_meta.index.get_level_values("Channel") == "Der Wahrheit verpflichtet"]
#      48 Schöpfer = df_meta.loc[df_meta.index.get_level_values("Channel") == "Schöpferwissen TV"]
#      49 Alles = df_meta.loc[df_meta.index.get_level_values("Channel") == "ALLESUNDNICHTS"]
#
# c:\Users\Stacky\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in _get_level_values(self, level)
#    2006         Index(['a', 'b', 'c'], dtype='object')
#    2007         """
# -> 2008         self._validate_index_level(level)
#    2009         return self
#    2010
#
# c:\Users\Stacky\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1929                 )
#    1930         elif level != self.name:
# -> 1931             raise KeyError(
#    1932                 f"Requested level ({level}) does not match index name ({self.name})"
#    1933             )
#
# KeyError: 'Requested level (Channel) does not match index name (None)'

# %%
import numpy as np
import networkx as nx


# unklar aber zusammenhängend
julia = pd.DataFrame({ 'from':["Creator Monkeys TV", "Schöpferwissen TV"], 
                   'to':['Julia', 'Julia']})

# HOnett und "der wahrheit" PErson A
PersonA =  pd.DataFrame({ 'from':["Der Wahrheit verpflichtet",  "Honett"], 
                   'to':['PersonA', 'PersonA']})
PersonB =  pd.DataFrame({ 'from':["Schöpferwissen Backup NEU siehe Kanalinfo (Youtube)",  "Schöpferwissen Ley (VK)", "Schöpferwissen TV - Backup Kanal (RuTube)"], 
                   'to':['PersonB', 'PersonB', "PersonB"]})
# selbe URL Namensänderung
Helga = pd.DataFrame({ 'from':["Rettung der Menschheit TV", 
                                 "Rettung der Menschheit mit dem Schwert des Wissens",
                                 "Rettung Menschheit UBC",
                                 "Es ist alles gesagt",
                                 "Aus die Maus",
                                 "Rettung Menschheit?"
                                 ], 
                   'to':['Helga', 'Helga', 'Helga', 'Helga', 'Helga', 'Helga']})

# Heiko:  "Der Weg in deine Freiheit", Mai 2019 - August 2021, Betreiber vermutlich Heiko, mit Links zu seinen diversen Blogs
Heiko =  pd.DataFrame({ 'from':["Der Weg in deine Freiheit"], 
                   'to':['Heiko']})
#Anka G. - F. Wau maumau:
Wau = pd.DataFrame({ 'from':["ausschn.de/",
                             "facebook.com/wau.maumau.3", 
                             "facebook.com/wau.maumau.33", 
                             "instagram.com/ungeeignet/", 
                             "u n endlich ", 
                             "guelty till 11.12.23", 
                             "___k__ungefähr"], 
                   'to':['WauMauMau', 'WauMauMau','WauMauMau','WauMauMau','WauMauMau','WauMauMau','WauMauMau']})

Cilgia =  pd.DataFrame({ 'from':["veritas lügensarg tv"], 
                   'to':['Cilgia']})

#Steffi: 
Steffi =  pd.DataFrame({ 'from':["Schöpferwissen TV UBC (ehemals Verloren und Wiedergefunden)"], 
                   'to':['Steffi']})

#Tinas_Inhalte:
Tina = pd.DataFrame({ 'from':["Schöpferwissen TV TIME FOR JUSTICE UBC",
                                      "Schöpferwissen TV UBC NOBODY KNOWS",
                                      "UBC - Schöpferwissen Thomas Veit - Wissensträger - NOBODYKNOWS",
                                      "Exit Matrix Eilt (Telegram gelöscht)"], 
                   'to':['Tina', 'Tina', 'Tina','Tina']})
Franz = pd.DataFrame({ 'from':[
                                      "WISSEN - NICHT VON DIESER WELT", 
                                      "Der verlorene Zwilling TV",  
                                      "ALLESUNDNICHTS",
                                      "Drachentöter TV",
                                      "WER HAT ANGST VORM SCHWARZEN MANN",  
                                      "Veit Club", 
                                      "SON GOKU TV",
                                      "PLANET VEIT"], 
                   'to':['Franz','Franz','Franz','Franz','Franz','Franz','Franz','Franz']})

UBC_TV =  pd.DataFrame({ 'from':["UBC TV"], 
                   'to':['?']})
Peek_TV = pd.DataFrame({ 'from':[ "Schöpferwissen- Peek-TV"], 
                   'to':[ "?"]})
Time = pd.DataFrame({ 'from':[ "The time is now"], 
                   'to':[  "?"]})
bewusst = pd.DataFrame({ 'from':[  "bewusstundso"], 
                  'to':[   "?"]})


frames = [PersonA,  PersonB, julia, Helga, Heiko, Cilgia, Steffi, Wau, Tina, Franz, UBC_TV, Peek_TV, Time, bewusst]
result = pd.concat(frames)
result.to_csv('networkII.csv', index=False)
"""# Build your graph
G=nx.from_pandas_edgelist(result, 'from', 'to')
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=1000, font_size=10, alpha=0.8, width=2)

plt.show()"""
# Out:
# "# Build your graph\nG=nx.from_pandas_edgelist(result, 'from', 'to')\npos = nx.spring_layout(G)\nnx.draw(G, pos, with_labels=True, node_size=1000, font_size=10, alpha=0.8, width=2)\n\nplt.show()"

# %% [markdown]
# ## Pie Chart

# %%
#toDO Legende lesbar machen
plt.figure().clear()
plt.close()
plt.cla()
plt.clf()
Title = "Total number of videos is "+ str(len(df_meta))               
number_of_vids =[]
for name in all_channel_names:
    number_of_vids.append(len(df_meta.loc[df_meta.index.get_level_values("Channel") == name]))
cumsum = np.cumsum(number_of_vids)
explode = [0.1]*8
#print(df_meta.shape)
fi1, ax1 = plt.subplots()
fi1.tight_layout() #tight margins
title = ax1.set_title(Title, loc="center",fontsize=20)
title.set_position([0.9, 1.2])
ax1.set_axis_on()
ax1.pie(number_of_vids, radius=1, wedgeprops={ "edgecolor": "black"}, textprops={'fontsize': 8}, colors= colors)
ax1.legend(all_channel_names, bbox_to_anchor=(0.99,0.95), loc="upper left", borderaxespad=0)

plt.show()
# Out:
# <ipython-input-3-0d5c3bffb69a>:19: UserWarning: The handle <matplotlib.patches.Wedge object at 0x000001EC33E26B20> has a label of '___________k______ungefähr' which cannot be automatically added to the legend.
#   ax1.legend(all_channel_names, bbox_to_anchor=(0.99,0.95), loc="upper left", borderaxespad=0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Duration

# %%
df_drop = df_meta
counter_len = 0
[df_meta, all_channel_names] = load_df()
print(df_meta["length"].head())
for length in Wahrheit["length"]:
    for lengthS in df_drop["length"]:
        if length == lengthS:
            counter_len += 1
print(df_meta["length"].head())
print("Videos on other channels with same length: %s" %counter_len)
print("Number of other Videos: %s" % df_drop.shape[0])

duration=0
list_of_length = []
#print(all_channel_names)
#get duration
for channel in all_channel_names:
    df = df_meta.loc[df_meta.index.get_level_values("Channel") == channel]
    
    secs = int(df["length"].sum(axis = 0, skipna = True)) 
    mins = secs/60
    hours = mins/60 
    days= hours/24
    print(f"channel {channel}")
    print(f"secs{secs}")
    print(f"hours{hours}")
    print(f"days{days}")
    print(f"*"*100)
    list_of_length.append(hours)
    duration = duration + days
    print(duration)
result = pd.DataFrame([all_channel_names, list_of_length]).transpose()
result = result.sort_values(1)
#print(result)

plt.figure(constrained_layout=True)
plt.barh(result[0], result[1], color = colors)
title = duration
plt.title("Duration of all Videos is %s Days" % round(title))

plt.xlabel("hours")
#plt.yticks(rotation=30)
plt.ylabel("")

plt.show()
#print(list_of_length)
#df.groupby(pd.to_datetime(df['Date']).dt.strftime('%b-%Y'), sort=False)['Rep'].size().plot()
#ax2.plot()
# Out:
#    Channel
# 0  ALLESUNDNICHTS    1691
# 1  ALLESUNDNICHTS    2648
# 2  ALLESUNDNICHTS     214
# 3  ALLESUNDNICHTS    2414
# 4  ALLESUNDNICHTS    1239
# Name: length, dtype: object
#    Channel
# 0  ALLESUNDNICHTS    1691
# 1  ALLESUNDNICHTS    2648
# 2  ALLESUNDNICHTS     214
# 3  ALLESUNDNICHTS    2414
# 4  ALLESUNDNICHTS    1239
# Name: length, dtype: object
# Videos on other channels with same length: 4990
# Number of other Videos: 4028
# channel ALLESUNDNICHTS
# secs107386
# hours29.829444444444444
# days1.2428935185185186
# ****************************************************************************************************
# 1.2428935185185186
# channel Aus die Maus
# secs0
# hours0.0
# days0.0
# ****************************************************************************************************
# 1.2428935185185186
# channel bewusstundso
# secs23438
# hours6.510555555555555
# days0.2712731481481481
# ****************************************************************************************************
# 1.5141666666666667
# channel Creator Monkeys TV
# secs17713
# hours4.920277777777778
# days0.20501157407407408
# ****************************************************************************************************
# 1.7191782407407408
# channel Der verlorene Zwilling TV
# secs29818
# hours8.282777777777778
# days0.34511574074074075
# ****************************************************************************************************
# 2.0642939814814816
# channel Der Wahrheit verpflichtet
# secs1625542
# hours451.5394444444444
# days18.814143518518517
# ****************************************************************************************************
# 20.878437499999997
# channel Der Weg in deine Freiheit
# secs74691
# hours20.7475
# days0.8644791666666666
# ****************************************************************************************************
# 21.742916666666662
# channel DRACHENTÖTER TV
# secs736446
# hours204.56833333333333
# days8.523680555555556
# ****************************************************************************************************
# 30.266597222222217
# channel guelty till 11.12.23
# secs15273
# hours4.242500000000001
# days0.17677083333333335
# ****************************************************************************************************
# 30.44336805555555
# channel Honett
# secs11632
# hours3.2311111111111113
# days0.13462962962962963
# ****************************************************************************************************
# 30.577997685185178
# channel PLANET VEIT
# secs30454
# hours8.459444444444445
# days0.3524768518518519
# ****************************************************************************************************
# 30.93047453703703
# channel Rettung der Menschheit TV
# secs112806
# hours31.334999999999997
# days1.3056249999999998
# ****************************************************************************************************
# 32.23609953703703
# channel Schöpferwissen TV - Backup NEU (siehe Kanalinfo)
# secs8467
# hours2.3519444444444444
# days0.09799768518518519
# ****************************************************************************************************
# 32.33409722222221
# channel Schöpferwissen TV UBC NOBODY KNOWS
# secs15948
# hours4.430000000000001
# days0.18458333333333335
# ****************************************************************************************************
# 32.51868055555555
# channel Schöpferwissen TV UBC
# secs8065
# hours2.2402777777777776
# days0.0933449074074074
# ****************************************************************************************************
# 32.612025462962954
# channel Schöpferwissen TV
# secs1643516
# hours456.53222222222223
# days19.022175925925925
# ****************************************************************************************************
# 51.63420138888888
# channel Schöpferwissen- Peek-TV
# secs4946
# hours1.373888888888889
# days0.05724537037037037
# ****************************************************************************************************
# 51.69144675925925
# channel SON GOKU TV
# secs2457
# hours0.6825
# days0.0284375
# ****************************************************************************************************
# 51.71988425925925
# channel u n endlich
# secs111534
# hours30.98166666666667
# days1.290902777777778
# ****************************************************************************************************
# 53.01078703703703
# channel UBC TV
# secs14684
# hours4.078888888888889
# days0.1699537037037037
# ****************************************************************************************************
# 53.18074074074074
# channel VEIT CLUB
# secs37242
# hours10.345
# days0.4310416666666667
# ****************************************************************************************************
# 53.611782407407404
# channel veritas lügensarg tv
# secs1479225
# hours410.8958333333333
# days17.12065972222222
# ****************************************************************************************************
# 70.73244212962962
# channel WER HAT ANGST VORM SCHWARZEN MANN
# secs20896
# hours5.804444444444444
# days0.24185185185185185
# ****************************************************************************************************
# 70.97429398148147
# channel WISSEN - NICHT VON DIESER WELT
# secs1020374
# hours283.4372222222222
# days11.809884259259258
# ****************************************************************************************************
# 82.78417824074073
# channel ___________k______ungefähr
# secs40904
# hours11.362222222222222
# days0.4734259259259259
# ****************************************************************************************************
# 83.25760416666665
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## EventPlot

# %%
from datetime import datetime
[df, all_channels] = load_df()
list_of_date =[]
list_of_list = []
now = datetime.now()
for df in df_collection:
    for p_date in df["publish_date"]:
        p_date =p_date.replace(" 00:00:00", "")
        dt = datetime.strptime(p_date, '%Y-%m-%d')
        diff  = (now - dt)
        #list_of_date.append(int(diff.days)*-1)
        list_of_date.append(dt)
    list_of_list.append(list_of_date)
    list_of_date = []
D= list_of_list
# plot:
fig, axx = plt.subplots(constrained_layout=True)
axx.eventplot(D, orientation="horizontal",  linelengths = 0.98, color = colors[:-1])
labels = [item.get_text() for item in axx.get_xticklabels()]
axx.yaxis.grid(color='gray', linestyle='dashed')
axx.set_yticks(range(24))
axx.set_yticklabels(ch_names)
title = plt.title("Upload Events")
title.set_position([0.2,1])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Growth of video corpus

# %%
import warnings
warnings.filterwarnings('ignore')


[df, all_channels] = load_df()             
fig, ax = plt.subplots(constrained_layout=True)
#print(all_channels)

for i, key in enumerate(all_channels):
    df_temp = df.loc[df_meta.index.get_level_values("Channel") == all_channels[i]]
    df_temp["one"] = 1
    #(df["one"].cumsum()) 
    
    for k, date in enumerate(df_temp["publish_date"]):
        df_temp["publish_date"].iloc[k] = date.replace(" 00:00:00", "")
    
    try: 
        x = [datetime.strptime(d, '%Y-%m-%d') for d in df_temp["publish_date"]]
    except:
        x = [datetime.strptime(d, r'%Y-%m-%d') for d in df_temp["publish_date"]]
    #print(df_temp["one"].sum())
    #print(df_temp.shape[0])
    CumSum = df_temp.shape[0]-df_temp["one"].cumsum()
    ax.plot(x ,CumSum, color= colors[i])

ax.set_ylabel("video count")
ax.set_xlabel("year")
ax.legend(all_channels, bbox_to_anchor=(0., 1.0, 1., .10), loc=3,ncol=3, mode="expand", borderaxespad=0.)
#axx.set(xlim=(0, 8), xticks=np.arange(1, 8),
#       ylim=(0, 8), yticks=np.arange(1, 3000))

#plt.title("Video Count over Time")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
