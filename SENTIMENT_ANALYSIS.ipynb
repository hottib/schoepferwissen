# %%
# !pip install googletrans
# !pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Requirement already satisfied: googletrans in c:\programdata\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: httpx==0.13.3 in c:\programdata\anaconda3\lib\site-packages (from googletrans) (0.13.3)
# Requirement already satisfied: chardet==3.* in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Requirement already satisfied: httpcore==0.9.* in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (0.9.1)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (1.2.0)
# Requirement already satisfied: hstspreload in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (2021.12.1)
# Requirement already satisfied: idna==2.* in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (2.8)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (1.5.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (2019.11.28)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\programdata\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\programdata\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\programdata\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\programdata\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (3.0.0)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Collecting vaderSentiment
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from vaderSentiment) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->vaderSentiment) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->vaderSentiment) (2019.11.28)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from googletrans import Translator
import pandas as pd
data = pd.read_csv("Der Weg in deine Freiheit.csv")
data
# Out:
#                                                 title   Youtube ID  views  \
# 0   UBC - una bella compania, das größte Projekt d...  qz66ZrN1PDc     14
# 1   Was ist Spiritualität, was wird damit bewirkt,...  CURvx1oAlf4      6
# 2                         Wo ist die Seele verankert?  cEtPN7fGwJk      2
# 3   Der Seelenplan-Glück und Unglück sind kein Zuf...  KdkFbHJEkVc      6
# 4     UPDATE, Die neusten Erkenntnisse über die Seele  XgHwfwy_kmw      5
# 5                   Was ist die Seele, kurz und knapp  vZmfqOQfHhQ      7
# 6                Was ist die Seele? Neue Erkenntnisse  xZSHkpzzIpU      7
# 7   Was ist in Chiang Mai wirklich los und warum b...  eyqqzLrKl2w     17
# 8   Was bedeutet das? - Frei von Besetzungen und F...  ncRovDXyMPo     11
# 9     Der Erkenntnisweg - Der Weg direkt am Abgrund!?  APwAQxY202U     13
# 10  Der Weg der Selbsterkenntnis - beobachte dich ...  eOl8C2elDNw     14
# 11              Was ist Angst und warum ist sie da??!  MCsaKIU3x-0     27
# 12      Es geht um alles, um jeden einzelnen von uns!  2H0UhEXy_X8     15
# 13  Der Gott in der Maschine - ein "Erfahrungsberi...  LYETq_rQ30E     14
# 14  Öffne deine Augen - Impulse für die eigene En...  ouS_1uOhZDY      6
# 15      Welchen Wolf "fütterst" du? - Anunnaki Teil 3  VUW07nX7kGY     11
# 16  Spiel des Lebens - wo soll es enden?!! - 3 Tag...  CGO5xhZfm98     27
# 17  verstrickter Betrug an der Menschheit - in all...  _jgwExjUchY     14
# 18          Warum hat der heutige Mensch kein Wissen?  vjfIny5w_9o     11
# 19                                    Life After Life  IiPMS8oZrhE      7
# 20  Wo ist dein WILLE? Finde die Wahrheit solange ...  l3TqmlwdudM      8
# 21  In Wahrhaftigkeit ist "Emotion" keine Emotion,...  wiBQ-H1-L1U     40
# 22                              Illusionen der Matrix  dqvng34SPSk     36
# 23  Transhumanismus - menschliche Roboter sind unt...  EwaLDpM1EmM     76
# 24                            Wille, handeln - Wissen  8aARKiPnURY     23
# 25                Verführerische Höflichkeit - warum?  tIzDEqKNqZI     16
# 26  Anunnaki Teil 2 - Was von der Öffentlichkeit v...  AyXRZBZQo6k    433
# 27  Anunnaki Teil 1 - Was von der Öffentlichkeit v...  AJpOJFstB50    164
# 28            Wie aus Göttern Affen wurden - Das Buch  j2huB5un_RM    209
# 29    Thomas sein Buch - Wie aus Göttern Affen wurden  o0DCPOgpwcU     58
# 30                           UBC - una bella compania  ztLPe4bsYBo     89
# 31  Das Strukturierte Prinzip der Liebe - was jede...  KqbWRs6DKaw     21
#
#                                           description date_published duration  \
# 0   UBC - una bella compania. Das größte wahrhafti...     2021-08-05    37:13
# 1   Viele Information werden offenbart. Auch von J...     2021-08-05    44:27
# 2   E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2021-08-05    10:37
# 3   Beitrag 2018. Die geistige Entwicklung hört ni...     2021-08-05    17:45
# 4   Erfahre mehr im FernstudiumE-Mail: wie.aus.goe...     2021-08-05     3:38
# 5   E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2021-08-05     1:19
# 6                                                 NaN     2021-08-05     3:30
# 7   Die Wahrheit kommt früher oder später immer an...     2021-08-05    23:05
# 8   Auf dem Weg zum SchöpferwissenBeitrag von 2016...     2021-08-05  1:15:57
# 9   Fernstudium im SchöpferwissenE-Mail: wie.aus.g...     2021-08-05  1:13:16
# 10  nimm dir die Zeit und höre hin, wichtige Infor...     2021-03-02  1:47:46
# 11  Song: Angst ist nur ein Gefühl- Böse Onklz E-M...     2021-03-02     4:12
# 12  E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2021-02-28  1:03:00
# 13  E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2021-02-28    29:31
# 14  E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2021-02-27    15:24
# 15  E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2021-02-27    44:27
# 16  "ältere" Erkenntisse - so aktuell wie nie E-Ma...     2021-02-14    39:25
# 17  E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2021-02-14    18:56
# 18  E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2021-02-14    23:06
# 19  .. die wahre Freiheit und Unabhängigkeit liegt...     2021-01-27    51:23
# 20  ... denn die Wege sind lang und der Tod ist ni...     2021-01-27    35:29
# 21  E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2019-06-23  1:42:41
# 22  E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2019-05-21  1:26:08
# 23  Mehr zu den Inhalten vom Video im Buch Wie aus...     2019-05-21  1:39:51
# 24  E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2019-05-21    23:49
# 25  Thomas klärt unter anderen kurz auf, warum es ...     2019-05-19     3:23
# 26  Der reptilianische PaktSchau es Dir an und und...     2019-05-19    17:03
# 27  E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2019-05-19  1:45:32
# 28  BuchbeschreibungDieses Buch wird Dir helfen da...     2019-05-19    12:49
# 29  Julias BuchbeschreibungDieses Buch wird Dir he...     2019-05-19    11:51
# 30  - Eine ehrenwerte Gesellschaft für die, die da...     2019-05-19    45:16
# 31  E-Mail: wie.aus.goetter.affen.wurden@gmail.com...     2019-05-19    12:50
#
#                                                  tags  \
# 0   Programme, Erfindungen der Matrix, Freimauerer...
# 1   Schöpferwissen, Freiheit, Liebe, Kontrolle, Ma...
# 2   Schöpferwissen, Freiheit, Liebe, Kontrolle, Ma...
# 3   Schöpferwissen, Freiheit, Liebe, Kontrolle, Ma...
# 4   Schöpferwissen, Freiheit, Liebe, Kontrolle, Ma...
# 5   Schöpferwissen, Freiheit, Liebe, Kontrolle, Ma...
# 6                                                 NaN
# 7   Schöpferwissen, Freiheit, Liebe, Kontrolle, Ma...
# 8   Schöpferwissen, Freiheit, Liebe, Kontrolle, Ma...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  Programme, Erfindungen der Matrix, Freimauerer...
# 14  Programme, Erfindungen der Matrix, Freimauerer...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  Programme, Erfindungen der Matrix, Freimauerer...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                                            transcript transcript language  \
# 0   [{'text': 'euro', 'start': 7.7, 'duration': 2....                  de
# 1   [{'text': 'ja hallo und herzlich willkommen be...                  de
# 2   [{'text': '[Musik]', 'start': 0.15, 'duration'...                  de
# 3   [{'text': 'haben sie schon mal darüber nachged...                  de
# 4   [{'text': 'die neuesten erkenntnisse', 'start'...                  de
# 5   [{'text': 'du bist herzer 35 liebevollen weil ...                  de
# 6   [{'text': 'auf jeden fall ist das ist es extre...                  de
# 7   [{'text': 'schöpferische tv- julia vor der kam...                  de
# 8   [{'text': '[Musik]', 'start': 7.39, 'duration'...                  de
# 9   [{'text': 'hallo und herzlich', 'start': 5.77,...                  de
# 10  [{'text': 'also zurück zum thema schaut doch m...                  de
# 11  [{'text': 'wir glauben dass schmerz und angst ...                  de
# 12  [{'text': 'wir sind auf aufnahmen', 'start': 5...                  de
# 13  [{'text': 'ich bin zutiefst dankbar dafür dass...                  de
# 14  [{'text': '[Musik]', 'start': 0.73, 'duration'...                  de
# 15  [{'text': 'hallo und herzlich', 'start': 5.88,...                  de
# 16  [{'text': 'hallo und herzlich willkommen', 'st...                  de
# 17  [{'text': 'ich habe hier abgewaschen habe ich ...                  de
# 18  [{'text': 'auch wenn ich hier sitze und größer...                  de
# 19  [{'text': '[Musik]', 'start': 2.79, 'duration'...                  de
# 20  [{'text': 'hallo im kanal schöpfer wissen tv',...                  de
# 21  [{'text': 'eröffnung auch noch mehr', 'start':...                  de
# 22  [{'text': '[Musik]', 'start': 6.3, 'duration':...                  de
# 23  [{'text': '[Musik]', 'start': 23.02, 'duration...                  de
# 24  [{'text': 'das beispiel wie gesagt an die jung...                  de
# 25  [{'text': 'warum gibt es diese möglichkeit', '...                  de
# 26  [{'text': 'heute eine magie 2 wir haben dazu d...                  de
# 27  [{'text': 'herzlich willkommen bei schöpfer wi...                  de
# 28  [{'text': 'hallo liebe zuhörer hier ist julia ...                  de
# 29  [{'text': 'die aus gittern aachen wurden ein s...                  de
# 30  [{'text': 'hallo und herzlich willkommen bei',...                  de
# 31  [{'text': '[Musik]', 'start': 0.33, 'duration'...                  de
#
#     transcript auto-generated  transcript translatable
# 0                         1.0                      1.0
# 1                         1.0                      1.0
# 2                         1.0                      1.0
# 3                         1.0                      1.0
# 4                         1.0                      1.0
# 5                         1.0                      1.0
# 6                         1.0                      1.0
# 7                         1.0                      1.0
# 8                         1.0                      1.0
# 9                         1.0                      1.0
# 10                        1.0                      1.0
# 11                        1.0                      1.0
# 12                        1.0                      1.0
# 13                        1.0                      1.0
# 14                        1.0                      1.0
# 15                        1.0                      1.0
# 16                        1.0                      1.0
# 17                        1.0                      1.0
# 18                        1.0                      1.0
# 19                        1.0                      1.0
# 20                        1.0                      1.0
# 21                        1.0                      1.0
# 22                        1.0                      1.0
# 23                        1.0                      1.0
# 24                        1.0                      1.0
# 25                        1.0                      1.0
# 26                        1.0                      1.0
# 27                        1.0                      1.0
# 28                        1.0                      1.0
# 29                        1.0                      1.0
# 30                        1.0                      1.0
# 31                        1.0                      1.0

# %%
text= data.transcript
text
# Out:
# 0     [{'text': 'euro', 'start': 7.7, 'duration': 2....
# 1     [{'text': 'ja hallo und herzlich willkommen be...
# 2     [{'text': '[Musik]', 'start': 0.15, 'duration'...
# 3     [{'text': 'haben sie schon mal darüber nachged...
# 4     [{'text': 'die neuesten erkenntnisse', 'start'...
# 5     [{'text': 'du bist herzer 35 liebevollen weil ...
# 6     [{'text': 'auf jeden fall ist das ist es extre...
# 7     [{'text': 'schöpferische tv- julia vor der kam...
# 8     [{'text': '[Musik]', 'start': 7.39, 'duration'...
# 9     [{'text': 'hallo und herzlich', 'start': 5.77,...
# 10    [{'text': 'also zurück zum thema schaut doch m...
# 11    [{'text': 'wir glauben dass schmerz und angst ...
# 12    [{'text': 'wir sind auf aufnahmen', 'start': 5...
# 13    [{'text': 'ich bin zutiefst dankbar dafür dass...
# 14    [{'text': '[Musik]', 'start': 0.73, 'duration'...
# 15    [{'text': 'hallo und herzlich', 'start': 5.88,...
# 16    [{'text': 'hallo und herzlich willkommen', 'st...
# 17    [{'text': 'ich habe hier abgewaschen habe ich ...
# 18    [{'text': 'auch wenn ich hier sitze und größer...
# 19    [{'text': '[Musik]', 'start': 2.79, 'duration'...
# 20    [{'text': 'hallo im kanal schöpfer wissen tv',...
# 21    [{'text': 'eröffnung auch noch mehr', 'start':...
# 22    [{'text': '[Musik]', 'start': 6.3, 'duration':...
# 23    [{'text': '[Musik]', 'start': 23.02, 'duration...
# 24    [{'text': 'das beispiel wie gesagt an die jung...
# 25    [{'text': 'warum gibt es diese möglichkeit', '...
# 26    [{'text': 'heute eine magie 2 wir haben dazu d...
# 27    [{'text': 'herzlich willkommen bei schöpfer wi...
# 28    [{'text': 'hallo liebe zuhörer hier ist julia ...
# 29    [{'text': 'die aus gittern aachen wurden ein s...
# 30    [{'text': 'hallo und herzlich willkommen bei',...
# 31    [{'text': '[Musik]', 'start': 0.33, 'duration'...
# Name: transcript, dtype: object
